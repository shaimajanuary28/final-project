# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpl

# %%
df= pd.read_csv("Maths.csv")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0   False  False  False    False    False    False  False  False  False
# 1   False  False  False    False    False    False  False  False  False
# 2   False  False  False    False    False    False  False  False  False
# 3   False  False  False    False    False    False  False  False  False
# 4   False  False  False    False    False    False  False  False  False
#
#     Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences     G1  \
# 0  False  ...   False     False  False  False  False   False     False  False
# 1  False  ...   False     False  False  False  False   False     False  False
# 2  False  ...   False     False  False  False  False   False     False  False
# 3  False  ...   False     False  False  False  False   False     False  False
# 4  False  ...   False     False  False  False  False   False     False  False
#
#       G2     G3
# 0  False  False
# 1  False  False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# school
# False    395
# Name: school, dtype: int64
#
# sex
# False    395
# Name: sex, dtype: int64
#
# age
# False    395
# Name: age, dtype: int64
#
# address
# False    395
# Name: address, dtype: int64
#
# famsize
# False    395
# Name: famsize, dtype: int64
#
# Pstatus
# False    395
# Name: Pstatus, dtype: int64
#
# Medu
# False    395
# Name: Medu, dtype: int64
#
# Fedu
# False    395
# Name: Fedu, dtype: int64
#
# Mjob
# False    395
# Name: Mjob, dtype: int64
#
# Fjob
# False    395
# Name: Fjob, dtype: int64
#
# reason
# False    395
# Name: reason, dtype: int64
#
# guardian
# False    395
# Name: guardian, dtype: int64
#
# traveltime
# False    395
# Name: traveltime, dtype: int64
#
# studytime
# False    395
# Name: studytime, dtype: int64
#
# failures
# False    395
# Name: failures, dtype: int64
#
# schoolsup
# False    395
# Name: schoolsup, dtype: int64
#
# famsup
# False    395
# Name: famsup, dtype: int64
#
# paid
# False    395
# Name: paid, dtype: int64
#
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df['studytime'] = df['studytime']/df['studytime'].max()
df['G3'] = df['G3']/df['G3'].max()

# %%
df['studytime'] = df['studytime']/df['studytime'].max()
df[['studytime','absences','G3']].head()
# Out:
#    studytime  absences    G3
# 0       0.50         6  0.30
# 1       0.50         4  0.30
# 2       0.50        10  0.50
# 3       0.75         2  0.75
# 4       0.50         4  0.50

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["G3"])

# set x/y labels and plot title
plt.pyplot.xlabel("G3")
plt.pyplot.ylabel("count")
plt.pyplot.title("G3 bins")
# Out:
# Text(0.5, 1.0, 'G3 bins')

# %%
bins = np.linspace(min(df["G3"]), max(df["G3"]), 4)
bins
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['G3-binned'] = pd.cut(df['G3'], bins, labels=group_names, include_lowest=True )
df[['G3','G3-binned']].head(10)
# Out:
#      G3 G3-binned
# 0  0.30       Low
# 1  0.30       Low
# 2  0.50    Medium
# 3  0.75      High
# 4  0.50    Medium
# 5  0.75      High
# 6  0.55    Medium
# 7  0.30       Low
# 8  0.95      High
# 9  0.75      High

# %%
df["G3-binned"].value_counts()
# Out:
# Medium    234
# High      100
# Low        61
# Name: G3-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["G3-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("G3")
plt.pyplot.ylabel("count")
plt.pyplot.title("G3 bins")
# Out:
# Text(0.5, 1.0, 'G3 bins')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(df["G3"], bins = 3)

# set x/y labels and3plot title
plt.pyplot.xlabel("G3")
plt.pyplot.ylabel("count")
plt.pyplot.title("G3 bins")
# Out:
# Text(0.5, 1.0, 'G3 bins')

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'G3-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df["sex"])
dummy_variable_1.head()
# Out:
#    F  M
# 0  1  0
# 1  1  0
# 2  1  0
# 3  1  0
# 4  1  0

# %%
dummy_variable_1.rename(columns={'F':'sex-F', 'M':'sex-M'}, inplace=True)
dummy_variable_1.head()
# Out:
#    sex-F  sex-M
# 0      1      0
# 1      1      0
# 2      1      0
# 3      1      0
# 4      1      0

# %%
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("sex", axis = 1, inplace=True)

# %%
df.head()
# Out:
#   school  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# 0     GP   18       U     GT3       A     4     4  at_home   teacher  course
# 1     GP   17       U     GT3       T     1     1  at_home     other  course
# 2     GP   15       U     LE3       T     1     1  at_home     other   other
# 3     GP   15       U     GT3       T     4     2   health  services    home
# 4     GP   16       U     GT3       T     3     3    other     other    home
#
#    ... Dalc  Walc  health  absences  G1  G2    G3 G3-binned sex-F sex-M
# 0  ...    1     1       3         6   5   6  0.30       Low     1     0
# 1  ...    1     1       3         4   5   5  0.30       Low     1     0
# 2  ...    2     3       3        10   7   8  0.50    Medium     1     0
# 3  ...    1     1       5         2  15  14  0.75      High     1     0
# 4  ...    1     2       5         4   6  10  0.50    Medium     1     0
#
# [5 rows x 35 columns]

# %%
df.to_csv('clean_df.csv')

# %%
df.drop(['famsize', 'health', 'activities', 'guardian', 'address' ,'traveltime' ,'romantic' , 'higher','nursery','famrel','Dalc','Walc','failures','Pstatus','paid'], axis=1, inplace=True)

# let's view the first five elements and see how the dataframe was changed
df.head()
# Out:
#   school  age  Medu  Fedu     Mjob      Fjob  reason  studytime schoolsup  \
# 0     GP   18     4     4  at_home   teacher  course       0.50       yes
# 1     GP   17     1     1  at_home     other  course       0.50        no
# 2     GP   15     1     1  at_home     other   other       0.50       yes
# 3     GP   15     4     2   health  services    home       0.75        no
# 4     GP   16     3     3    other     other    home       0.50        no
#
#   famsup internet  freetime  goout  absences  G1  G2    G3 G3-binned  sex-F  \
# 0     no       no         3      4         6   5   6  0.30       Low      1
# 1    yes      yes         3      3         4   5   5  0.30       Low      1
# 2     no      yes         3      2        10   7   8  0.50    Medium      1
# 3    yes      yes         2      2         2  15  14  0.75      High      1
# 4    yes       no         3      2         4   6  10  0.50    Medium      1
#
#    sex-M
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
print(df.shape)
# Out:
# (395, 20)

# %%
age = df.age
age.head()
# Out:
# 0    18
# 1    17
# 2    15
# 3    15
# 4    16
# Name: age, dtype: int64

# %%
df.set_index('age', inplace=True)

# %%
df.tail()
# Out:
#     school  Medu  Fedu      Mjob      Fjob  reason  studytime schoolsup  \
# age
# 20      MS     2     2  services  services  course       0.50        no
# 17      MS     3     1  services  services  course       0.25        no
# 21      MS     1     1     other     other  course       0.25        no
# 18      MS     3     2  services     other  course       0.25        no
# 19      MS     1     1     other   at_home  course       0.25        no
#
#     famsup internet  freetime  goout  absences  G1  G2    G3 G3-binned  sex-F  \
# age
# 20     yes       no         5      4        11   9   9  0.45    Medium      0
# 17      no      yes         4      5         3  14  16  0.80      High      0
# 21      no       no         5      3         3  10   8  0.35    Medium      0
# 18      no      yes         4      1         0  11  12  0.50    Medium      0
# 19      no      yes         2      3         5   8   9  0.45    Medium      0
#
#      sex-M
# age
# 20       1
# 17       1
# ...

# %%
print(type(df.columns))
print(type(df.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.numeric.Int64Index'>

# %%
df.columns.tolist()
df.index.tolist()

print (type(df.columns.tolist()))
print (type(df.index.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %%
df.shape
# Out:
# (395, 19)

# %%
df.describe()
# Out:
#              Medu        Fedu   studytime    freetime       goout    absences  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     2.749367    2.521519    0.508861    3.235443    3.108861    5.708861
# std      1.094735    1.088201    0.209810    0.998862    1.113278    8.003096
# min      0.000000    0.000000    0.250000    1.000000    1.000000    0.000000
# 25%      2.000000    2.000000    0.250000    3.000000    2.000000    0.000000
# 50%      3.000000    2.000000    0.500000    3.000000    3.000000    4.000000
# 75%      4.000000    3.000000    0.500000    4.000000    4.000000    8.000000
# max      4.000000    4.000000    1.000000    5.000000    5.000000   75.000000
#
#                G1          G2          G3       sex-F       sex-M
# count  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    10.908861   10.713924    0.520759    0.526582    0.473418
# std      3.319195    3.761505    0.229072    0.499926    0.499926
# ...

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print ('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.5.1

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df[['G1','G2', 'G3']].hist(figsize=(14, 9),bins=16,edgecolor='k',grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'G1'}>,
#         <AxesSubplot:title={'center':'G2'}>],
#        [<AxesSubplot:title={'center':'G3'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot.bar(x='studytime', y='G3',rot=0);

# %%
df.set_index('school', inplace=True)

# %%
GP = df.loc['GP', 'G3'] 
GP.head()
# Out:
# school
# GP    0.30
# GP    0.30
# GP    0.50
# GP    0.75
# GP    0.50
# Name: G3, dtype: float64

# %%
GP.plot()
# Out:
# <AxesSubplot:xlabel='school'>

# %%
GP.index = GP.index.map(str) # let's change the index values of Haiti to type integer for plotting
GP.plot(kind='line')

plt.title('Grades from GP school')
plt.ylabel('Level1-Grades')
plt.xlabel('school')
# Out:
# Text(0.5, 0, 'school')
